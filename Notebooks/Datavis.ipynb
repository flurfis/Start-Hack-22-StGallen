# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.7 MB 4.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 247 kB 3.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 503 kB 1.7 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
verlaufe = pd.read_csv('../Data/verlaufe-sozialhilfe-ruckerstattungen-stadt-stgallen.csv',delimiter=';')
verlaufe
# Out:
#             ID Dossier von Dossier bis              Produkt
# 0      id02270     2021-08     2021-12  Sozialhilfeleistung
# 1      id03410     2019-08     2021-01  Sozialhilfeleistung
# 2      id01383     2019-02     2019-05  Sozialhilfeleistung
# 3      id02268     2019-07     2021-12  Sozialhilfeleistung
# 4      id04133     2019-07     2020-02  Sozialhilfeleistung
# ...        ...         ...         ...                  ...
# 13919  id03142     2022-03         NaN       Rückerstattung
# 13920  id04457     2012-12     2016-01  Sozialhilfeleistung
# 13921  id04457     2016-02     2017-11  Sozialhilfeleistung
# 13922  id01252     2016-01     2016-04                  NaN
# 13923  id00079     2020-12     2021-12  Sozialhilfeleistung
#
# [13924 rows x 4 columns]

# %%
eigenschaften = pd.read_csv('../Data/eigenschaften-sozialhilfeempfaenger-stadt-st-gallen.csv', delimiter=';')
eigbbenschaften
# Out:
#            id Dossierstruktur      Dossier Art Produkt letzte Dossierversion  \
# 0     id01115     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 1     id03188     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 2     id02902     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 3     id04640     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 4     id03380     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# ...       ...             ...              ...                           ...
# 4706  id02935     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 4707  id01973     Sozialhilfe  Ausländer/innen                Rückerstattung
# 4708  id02702     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 4709  id01194     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
# 4710  id00694     Sozialhilfe  Ausländer/innen           Sozialhilfeleistung
#
# ...

# %%
from datetime import date
date_dic = {1:"31", 2:"28", 3:"31", 4:"30", 5:"31", 6:"30", 7:"31", 8:"31", 9:"30", 10:"31", 11:"30", 12:"31"}
def properdate_end(fakedate):
    if fakedate is None:
        return None
    else:
        split_list = fakedate.split("-")
        split_list.append(date_dic[int(split_list[1])])
        xy = "-".join(split_list)
    return date.fromisoformat(xy)

# %%
test = '2021-08'
date2 = properdate_end(test)
date1 = date.fromisoformat('2021-08-01')
date2
# Out:
# datetime.date(2021, 8, 31)

# %%
date_dic[1]
# Out:
# '31'

# %%
from dateutil import relativedelta

r = relativedelta.relativedelta(date1, date2)

months_difference = (r.years * 12) + r.months + 1
months_difference
# Out:
# 1

# %%
type(months_difference)
# Out:
# int

# %%
today = date.today()

# %%
today
# Out:
# datetime.date(2022, 3, 24)
